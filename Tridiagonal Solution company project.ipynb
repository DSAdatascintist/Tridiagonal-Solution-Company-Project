# %%
#import the all necessary library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#extract the data set
data=pd.read_csv('C:/Users/SAI BABA/Desktop/gt.csv')

# %%
data
# Out:
#           AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0     9.3779  1020.1  90.262  2.3927  19.166  1043.6  541.16  110.16  10.564
# 1     9.2985  1019.9  89.934  2.3732  19.119  1039.9  538.94  109.23  10.572
# 2     9.1337  1019.8  89.868  2.3854  19.178  1041.0  539.47  109.62  10.543
# 3     8.9715  1019.3  89.490  2.3825  19.180  1037.1  536.89  108.88  10.458
# 4     9.0157  1019.1  89.099  2.4044  19.206  1043.5  541.25  110.09  10.464
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7147  4.8631  1027.0  81.084  4.2825  34.045  1100.0  529.98  168.38  14.290
# 7148  4.5173  1027.4  80.813  4.2481  33.904  1100.1  530.47  168.07  14.344
# 7149  4.2717  1027.9  80.380  4.2817  34.165  1099.9  529.56  168.55  14.395
# 7150  4.0853  1028.6  78.907  4.2313  33.802  1100.1  530.61  167.98  14.343
# 7151  4.2148  1029.4  70.679  4.2049  33.768  1100.0  530.97  167.30  14.291
#
#            CO      NOX
# ...

# %% [markdown]
# data contains 7152 rows and 11 columns

# %%
data.shape
# Out:
# (7152, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7152 entries, 0 to 7151
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      7152 non-null   float64
#  1   AP      7152 non-null   float64
#  2   AH      7152 non-null   float64
#  3   AFDP    7152 non-null   float64
#  4   GTEP    7152 non-null   float64
#  5   TIT     7152 non-null   float64
#  6   TAT     7152 non-null   float64
#  7   TEY     7152 non-null   float64
#  8   CDP     7152 non-null   float64
#  9   CO      7152 non-null   float64
#  10  NOX     7152 non-null   float64
# dtypes: float64(11)
# memory usage: 614.8 KB

# %% [markdown]
# it gives the information about the dataset ,data has float 64 datatype

# %%
data.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %% [markdown]
# there is no any NULL values present in the dataset

# %%
data.describe(include='all')
# Out:
#                AT           AP           AH         AFDP         GTEP  \
# count  7152.00000  7152.000000  7152.000000  7152.000000  7152.000000
# mean     17.60262  1011.999607    80.461624     3.695958    25.105097
# std       6.86289     6.290065    14.125390     0.805829     4.350711
# min       0.28985   989.380000    27.504000     2.329500    18.104000
# 25%      12.04875  1008.400000    71.493500     3.100350    21.385000
# 50%      17.20450  1011.800000    84.002000     3.627850    24.852500
# 75%      23.16400  1016.000000    91.579000     4.156825    26.385750
# max      33.87300  1029.700000   100.190000     6.977900    36.950000
#
#                TIT          TAT          TEY          CDP           CO  \
# count  7152.000000  7152.000000  7152.000000  7152.000000  7152.000000
# mean   1081.569463   545.780885   132.168342    11.971586     2.723031
# std      17.385147     7.358935    16.348156     1.132159     2.363913
# ...

# %% [markdown]
# table gives the detail description about the dataset .with its total count,mean,std,and also how the data is distributed with its mini to maximum values in the specific column

# %%
data.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %%
data['AP'].unique()
# Out:
# array([1020.1 , 1019.9 , 1019.8 , 1019.3 , 1019.1 , 1019.  , 1019.2 ,
#        1019.5 , 1019.6 , 1019.7 , 1018.7 , 1018.2 , 1018.3 , 1018.4 ,
#        1018.5 , 1018.8 , 1019.4 , 1020.  , 1020.5 , 1020.9 , 1021.2 ,
#        1021.3 , 1021.  , 1021.4 , 1021.6 , 1021.9 , 1022.4 , 1022.9 ,
#        1023.3 , 1023.8 , 1024.  , 1024.1 , 1024.3 , 1024.8 , 1025.3 ,
#        1025.4 , 1025.8 , 1026.4 , 1026.7 , 1027.2 , 1027.7 , 1027.3 ,
#        1026.8 , 1026.3 , 1026.  , 1025.9 , 1025.7 , 1025.6 , 1025.5 ,
#        1025.2 , 1024.4 , 1023.9 , 1023.4 , 1022.6 , 1021.1 , 1020.8 ,
#        1020.6 , 1020.2 , 1018.  , 1016.9 , 1016.3 , 1016.  , 1015.6 ,
#        1015.3 , 1015.1 , 1015.  , 1014.6 , 1014.2 , 1013.9 , 1013.4 ,
#        1012.9 , 1012.7 , 1012.2 , 1011.8 , 1011.6 , 1011.4 , 1011.1 ,
#        1010.8 , 1010.1 , 1008.9 , 1008.1 , 1007.7 , 1007.3 , 1007.1 ,
#        1006.8 , 1006.6 , 1006.5 , 1006.3 , 1006.  , 1005.9 , 1005.7 ,
# ...

# %%
#let will find out the correlation between the independent and dependant variables
data.corr()
# Out:
#             AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# AT    1.000000 -0.224382 -0.598627  0.583369 -0.043098  0.112788  0.332060
# AP   -0.224382  1.000000 -0.019056  0.022045  0.207948  0.163417 -0.236419
# AH   -0.598627 -0.019056  1.000000 -0.477844 -0.188930 -0.251603  0.005067
# AFDP  0.583369  0.022045 -0.477844  1.000000  0.624854  0.644273 -0.326829
# GTEP -0.043098  0.207948 -0.188930  0.624854  1.000000  0.896211 -0.770147
# TIT   0.112788  0.163417 -0.251603  0.644273  0.896211  1.000000 -0.415352
# TAT   0.332060 -0.236419  0.005067 -0.326829 -0.770147 -0.415352  1.000000
# TEY  -0.165419  0.226761 -0.115436  0.540439  0.981677  0.917162 -0.722024
# CDP  -0.069336  0.229323 -0.181624  0.612137  0.996149  0.912384 -0.748264
# CO   -0.157783 -0.109782  0.247851 -0.479581 -0.642176 -0.806942  0.155655
# NOX  -0.581687  0.096800  0.182527 -0.386677 -0.024444 -0.122998 -0.179357
#
#            TEY       CDP        CO       NOX
# ...

# %%
#heat map
plt.figure(figsize=(22,7))
sns.heatmap(data.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# heatmap shows that 'AH','TAT','NOX' has a positive correlation with the CO emission as this parameter increases the CO EMISSION also goes on increasing

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#now lets see how data is distributed in each column
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=11:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# the plot shows that column 'AT','AP' has uniform distribution of data also NOX has uniformity with certain Skewness

# %%
# checking the skewness for the features:
data.skew()
# Out:
# AT      0.109946
# AP     -0.056875
# AH     -0.805210
# AFDP    0.827222
# GTEP    0.438431
# TIT    -0.819860
# TAT    -1.513150
# TEY     0.162309
# CDP     0.297322
# CO      2.521872
# NOX     1.023974
# dtype: float64

# %%
import numpy as np

# %%
#remove skewness
data['AH']=np.sqrt(data['AH'])
data['AFDP']=np.sqrt(data['AFDP'])
data['TIT']=np.sqrt(data['TIT'])
data['TAT']=np.sqrt(data['TAT'])

# %%
data.skew()
# Out:
# AT      0.109946
# AP     -0.056875
# AH     -1.012490
# AFDP    0.514356
# GTEP    0.438431
# TIT    -0.828591
# TAT    -1.519006
# TEY     0.162309
# CDP     0.297322
# CO      2.521872
# NOX     1.023974
# dtype: float64

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
data.hist(figsize=(20,20), grid = True, layout = (4,3), bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'AT'}>,
#         <AxesSubplot:title={'center':'AP'}>,
#         <AxesSubplot:title={'center':'AH'}>],
#        [<AxesSubplot:title={'center':'AFDP'}>,
#         <AxesSubplot:title={'center':'GTEP'}>,
#         <AxesSubplot:title={'center':'TIT'}>],
#        [<AxesSubplot:title={'center':'TAT'}>,
#         <AxesSubplot:title={'center':'TEY'}>,
#         <AxesSubplot:title={'center':'CDP'}>],
#        [<AxesSubplot:title={'center':'CO'}>,
#         <AxesSubplot:title={'center':'NOX'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#plotting the boxplot of each column to check the outliers 
data.plot(kind='box',subplots = True,layout=(4,3),figsize = (15,10))
# Out:
# AT          AxesSubplot(0.125,0.71587;0.227941x0.16413)
# AP       AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# AH       AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# AFDP       AxesSubplot(0.125,0.518913;0.227941x0.16413)
# GTEP    AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# TIT     AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# TAT        AxesSubplot(0.125,0.321957;0.227941x0.16413)
# TEY     AxesSubplot(0.398529,0.321957;0.227941x0.16413)
# CDP     AxesSubplot(0.672059,0.321957;0.227941x0.16413)
# CO            AxesSubplot(0.125,0.125;0.227941x0.16413)
# NOX        AxesSubplot(0.398529,0.125;0.227941x0.16413)
# dtype: object

# %%
import numpy as np
from scipy.stats import zscore

# %%
#calculate the zscore
z = np.abs(zscore(data))
print(z)
# Out:
# [[1.19851771 1.28789758 0.68693997 ... 1.24336352 2.80240084 2.38500302]
#  [1.21008799 1.25609918 0.66607748 ... 1.23629688 3.50839828 2.84560007]
#  [1.23410288 1.24019998 0.66187494 ... 1.26191346 3.39586513 2.77753563]
#  ...
#  [1.94260035 2.52803509 0.04076679 ... 2.14067454 0.70897184 0.60271072]
#  [1.96976282 2.63932948 0.05888428 ... 2.09474137 0.69192265 0.6621426 ]
#  [1.9508919  2.76652307 0.63350066 ... 2.0488082  0.67237742 0.74224282]]

# %%
threshold=3
print(np.where(z<3))
print(data.shape)
# Out:
# (array([   0,    0,    0, ..., 7151, 7151, 7151], dtype=int64), array([ 0,  1,  2, ...,  8,  9, 10], dtype=int64))
# (7152, 11)

# %%
#Assign the value to df_new which are less the threshold value and removing the outliers
data_new=data[(z<3).all(axis = 1)]

# %%
print(data.shape)
print(data_new.shape)
data = data_new
print('Shape after removing outlires',data.shape)
# Out:
# (7152, 11)
# (6772, 11)
# Shape after removing outlires (6772, 11)

# %%
# setup figure,lets we will plot the scatter plot to see how the different variable are correlated with the CO
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(16, 20))

# iterate and plot subplots
for xcol, ax in zip(data.columns[:], [x for v in axes for x in v]):
    data.plot.scatter(x=xcol, y='CO', ax=ax, alpha=0.5, color='r')

# %% [markdown]
# from AT and CO Scatter plot is seen that with the increse of ambient temp there is increse in the CO more data is concentared below the CO level of 6.
# also from the AP and CO scatter plot also shows that with increse in AP there is increse in the CO ,same condition is for AH,one more imporatant observation in case of AH is with the AH of 9 to 10 there is large increse in the CO
# for 'AFDP'in initial case when the AFDP is low there is sudden increse in the CO gradually it goes on reducing as the AFDP increses,same case for GTEP,as the turbine inlet temp is low intitially then CO also low when it increses CO goes on reducing from 32.6 to 33 again with increse in temp beyond that there is some increse in the CO emission
# in case of TAT initially with increse in the TAT there is no that much change in the CO but as it goes beyond the 23.3 there is sudden raise in the emission of CO
# Also if we see the scatter plot of CO and NOX it is seen that they are directly proportional to each other

# %%
# setup figure
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(16, 20))

# iterate and plot subplots
for xcol, ax in zip(data.columns[:], [x for v in axes for x in v]):
    data.plot.scatter(x=xcol, y='NOX', ax=ax, alpha=0.5, color='r')

# %% [markdown]
# from scatter plot we can say that initially as the ambient temp is low there is increse in the NOX emission further it slightly goes on reducing
# for 'AP','AH','TAT','TIT','GTEP','TEY','CDP','CO'we can see that with the increse in the above parameter NOX emission also goes on incresing so there is linear relationship between above parameter with target variable

# %%
#assign the value of x and y for training and testing phase
x=data[['AP','AP','AH','TIT','TAT','NOX']]
y = data[['CO']]
print(x.shape)
print(y.shape)
# Out:
# (6772, 6)
# (6772, 1)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LogisticRegression,Lasso,LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.decomposition import PCA
from scipy.stats import zscore
from sklearn.model_selection import cross_val_score

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x)
x = pd.DataFrame(x,columns=x.columns)

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
max_r2_score = 0
for r_state in range(1,50):
    train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = r_state,test_size = 0.25)
    for i in model:
        i.fit(train_x,train_y)
        pre = i.predict(test_x)
        r2_sc = r2_score(test_y,pre)
        print("R2 score correspond to random state " ,r_state ,"is", r2_sc)
        if r2_sc> max_r2_score:
            max_r2_score=r2_sc
            final_state = r_state
            final_model = i
            
print()
print()
print()
print()
print("max R2 score correspond to random state " ,final_state , "is" , max_r2_score ,"and model is",final_model)
# Out:
# R2 score correspond to random state  1 is 0.6046186804437786
# R2 score correspond to random state  1 is 0.41755390032747897
# R2 score correspond to random state  1 is 0.5680074839718188
# R2 score correspond to random state  1 is 0.7107065928966416
# R2 score correspond to random state  1 is 0.780990209620056
# R2 score correspond to random state  2 is 0.6490916742223589
# R2 score correspond to random state  2 is 0.40051342282155256
# R2 score correspond to random state  2 is 0.6148444321801767
# R2 score correspond to random state  2 is 0.7327479775098851
# R2 score correspond to random state  2 is 0.805353642714428
# R2 score correspond to random state  3 is 0.6237491487372739
# R2 score correspond to random state  3 is 0.4021524657481583
# R2 score correspond to random state  3 is 0.5893194429335129
# R2 score correspond to random state  3 is 0.703478758647065
# R2 score correspond to random state  3 is 0.7689967483574738
# ...

# %%
#assign the value of x and y for training and testing phase
x_ = data[['AP','AH','TAT','TIT','GTEP','TEY','CDP','CO']]
y_ = data[['NOX']]
print(x_.shape)
print(y_.shape)
# Out:
# (6772, 8)
# (6772, 1)

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
max_r2_score = 0
for r_state in range(1,50):
    train_x,test_x,train_y,test_y = train_test_split(x_,y_,random_state = r_state,test_size = 0.25)
    for i in model:
        i.fit(train_x,train_y)
        pre = i.predict(test_x)
        r2_sc = r2_score(test_y,pre)
        print("R2 score correspond to random state " ,r_state ,"is", r2_sc)
        if r2_sc> max_r2_score:
            max_r2_score=r2_sc
            final_state = r_state
            final_model = i
            
print()
print()
print()
print()
print("max R2 score correspond to random state " ,final_state , "is" , max_r2_score ,"and model is",final_model)
# Out:
# R2 score correspond to random state  1 is 0.5859430708191893
# R2 score correspond to random state  1 is 0.7194326745164348
# R2 score correspond to random state  1 is 0.4458092367355647
# R2 score correspond to random state  1 is 0.44808661109158177
# R2 score correspond to random state  1 is 0.722811992512414
# R2 score correspond to random state  2 is 0.6083277725639407
# R2 score correspond to random state  2 is 0.6852121038559883
# R2 score correspond to random state  2 is 0.4533888857565188
# R2 score correspond to random state  2 is 0.4526262039435057
# R2 score correspond to random state  2 is 0.7223214321024688
# R2 score correspond to random state  3 is 0.6212296363267099
# R2 score correspond to random state  3 is 0.6975639010307637
# R2 score correspond to random state  3 is 0.48748739828007726
# R2 score correspond to random state  3 is 0.45955548909015276
# R2 score correspond to random state  3 is 0.7210298074774051
# ...

# %%
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)
x_scaled
# Out:
# array([[ 1.31659897,  1.31659897,  0.69609457, -2.39246577, -0.69156544,
#          2.86923678],
#        [ 1.13912493,  1.13912493,  0.60206095, -2.39869576, -0.73221854,
#          2.71345757],
#        [ 1.17139294,  1.17139294,  0.59582819, -2.38623607, -0.76306609,
#          2.32150317],
#        ...,
#        [ 2.5750512 ,  2.5750512 ,  0.02013776,  1.06886923, -2.3262793 ,
#          0.79937827],
#        [ 2.68798922,  2.68798922, -0.08410647,  1.0810053 , -2.17757725,
#          0.86839926],
#        [ 2.81706124,  2.81706124, -0.68520826,  1.0749374 , -2.12662757,
#          0.96142336]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=6)

# %%
dbr=GradientBoostingRegressor()

# %%
dbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred=dbr.predict(x_test)

# %%
y_pred
# Out:
# array([3.45534302, 3.19129786, 3.83118349, ..., 2.34480729, 2.35040088,
#        7.0729966 ])

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.8140837592372432

# %% [markdown]
# # cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(2,20):
    cv=cross_val_score(dbr,x,y,cv=i)
    print(dbr,cv.mean())
# Out:
# GradientBoostingRegressor() 0.6538059627055564
# GradientBoostingRegressor() 0.656367387407306
# GradientBoostingRegressor() 0.6631231699353475
# GradientBoostingRegressor() 0.693649840634569
# GradientBoostingRegressor() 0.6785843315717034
# GradientBoostingRegressor() 0.7076287770272828
# GradientBoostingRegressor() 0.7134959058279714
# GradientBoostingRegressor() 0.7253454464073956
# GradientBoostingRegressor() 0.7374857965839018
# GradientBoostingRegressor() 0.7310516161476709
# GradientBoostingRegressor() 0.7211519906813182
# GradientBoostingRegressor() 0.7282197546538044
# GradientBoostingRegressor() 0.7488700627665502
# GradientBoostingRegressor() 0.7440343968733854
# GradientBoostingRegressor() 0.7500086490370299
# GradientBoostingRegressor() 0.709169257465499
# GradientBoostingRegressor() 0.7382244138663199
# GradientBoostingRegressor() 0.7569413894408198

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('actual_CO')
plt.ylabel('predicted_CO')
plt.title('actual Vs model prediction')
plt.show()

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
from sklearn.linear_model import Lasso
warnings.filterwarnings('ignore')

# %%
parameters={'alpha':[.0001,0.001,.01,.1,1,10],'random_state':list(range(0,30))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
from sklearn.metrics import r2_score

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.755526294376464

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('R2score:',rfs*100)
# Out:
# R2score: 84.2184150957781

# %% [markdown]
# # Saving Model For CO emission

# %%
#saving model
import joblib
joblib.dump(dbr,'CO_prediction')
# Out:
# ['CO_prediction']

# %%
loaded_model=joblib.load('CO_prediction')
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.8140837592372432

# %% [markdown]
# # Saving Model For NOX emission

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=16)

# %%
dbr1=GradientBoostingRegressor()

# %%
dbr1.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1=dbr1.predict(x_test)

# %%
y_pred1
# Out:
# array([1.88765612, 4.32404365, 2.1270987 , ..., 1.1534678 , 3.60449667,
#        1.92655403])

# %%
print(r2_score(y_test,y_pred1))
# Out:
# 0.7820238127520069

# %%
#saving model
import joblib
joblib.dump(dbr1,'NOX_prediction')
# Out:
# ['NOX_prediction']

# %%
loaded_model=joblib.load('NOX_prediction')
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.7820238127520069
